# %% [markdown]
# # Capstone Project
#
# ## *Recommender System*
#
# #### Table of Contents
#
# * [Topic 1](#topic-1)
# * [Topic 2](#topic-2)
#
# ### Import Libraries & Read in Data

# %%
## standard imports 
import pandas as pd 
import numpy as np
import re
## visualizations
import matplotlib.pyplot as plt
import seaborn as sns

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity

### Spotify Credentials - must be set in local environment to run
auth_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(auth_manager=auth_manager)

## options
# pd.options.display.max_rows = 4000
# pd.options.display.max_columns = 100
# pd.set_option('max_colwidth', 100)

# %%
### read in data
df = pd.read_csv('../data/hiphop_clustering.csv')
track = pd.read_csv('../data/WAP.csv')

# %%
df.head(2)
# Out:
#   artist_name                track_id  popularity  acousticness  danceability  \
# 0     J. Cole  2JvzF1RMd7lE3KmFlsyZD8        0.96         0.149         0.837
# 1   Meek Mill  2IRZnDFmlqMuOrYOLnZZyc        0.95         0.259         0.889
#
#    energy  instrumentalness  liveness  loudness  speechiness    tempo  valence
# 0   0.364               0.0     0.271   -11.713       0.2760  123.984    0.463
# 1   0.496               0.0     0.252    -6.365       0.0905   86.003    0.544

# %%
track.drop(columns=['key', 'mode'], inplace=True)  ### not present in test set using here

# %%
track
# Out:
#   artist_name                track_id  popularity  danceability  energy  \
# 0     Cardi B  4Oun2ylbjFKMPTiaSbbCih        0.97         0.935   0.454
#
#    loudness  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0    -7.509        0.375        0.0194                 0    0.0824    0.357
#
#      tempo
# 0  133.073

# %%
# pd.concat([df, track], ignore_index=True)

# %% [markdown]
# ## Recommender Functions <a class="anchor" id="topic-1"></a>
# <hr/>

# %%
def track_reccommender(df, track, include_pop=True):
    ID = track['track_id'].values[0]
    ### Create X data
    data = pd.concat([df, track], ignore_index=True)
    ### desired features for model (may change later)
    features = ['popularity', 'acousticness', 'danceability', 'energy', 'speechiness', 'valence']
    if include_pop==False:
        features.remove('popularity')
    X = data[features]
    ### calculate similarity matrix
    similarity_matrix = cosine_similarity(X, X)
    
    ### create mapping bwtn track ids and index
    track_id_map = pd.Series(data.index, index=data['track_id'])
    ## find index of track in dataframe
    track_index = track_id_map[ID]
    ### find the correct column for the track in the similarity matrix
#     similarity_scores = list(enumerate(similarity_matrix[track_index]))
    

#     ### above creates list of tuples, score for each track is second element from each tuple
#     similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    
#     ### select top 15 matches
#     similarity_scores_top15 = similarity_scores[:15]
    
#     ### get indices for top 15 tracks to pull from dataframe
#     recc_track_idxs = [i[0] for i in similarity_scores_top15]
#     ### get scores for top 15
#     recc_track_scores = [i[1] for i in similarity_scores_top15]
    
    ### USING SERIES INSTEAD
    similarity_scores = pd.Series(similarity_matrix[track_index])
    similarity_scores.sort_values(ascending=False, inplace=True)
    
    similarity_scores_top15 = similarity_scores[:15]
    recc_track_ids = data['track_id'].loc[similarity_scores_top15.index]
    
    ### created dataframe of reccommended tracks
    recc_tracks_df = data[data['track_id'].isin(recc_track_ids.values)].copy()
    recc_tracks_df['score'] = similarity_scores
    recc_tracks_df.sort_values(by='score', ascending=False, inplace=True)

    return recc_tracks_df

def make_track_URIs(track_ids):
    ### reformats track ids as track URIs
    ### need text spotify:track: in front of each ID to use in Spotify
    track_URIs = []
    for track_id in track_ids:
        uri = 'spotify:track:'+ track_id
        track_URIs.append(uri)
    return track_URIs

def create_playlist_file(track_ids, name):
    ### creates text file of Spotify URIs
    track_URIs = make_track_URIs(track_ids)
    ### write URIs to text file
    playlist = open(fr'../playlists/playlist_{name}.txt','w')
    playlist.writelines('%s\n' % track for track in track_URIs) 
    playlist.close()
    pass

def display_playlist(playlist_tracks):
    ### displays playlist track name, artist, album
    tracks_dict = sp.tracks(playlist_tracks)['tracks']
    playlist_info = []
    for i in range(len(playlist_tracks)):
        track = [
            tracks_dict[i]['name'], 
            tracks_dict[i]['artists'][0]['name'],
            tracks_dict[i]['album']['name']
            ]
        playlist_info.append(track)
    
    playlist_df = pd.DataFrame(playlist_info, columns=['Title', 'Artist', 'Album'] )
    ### start index at 1
    playlist_df.index = np.arange(1,len(playlist_df)+1)
    return playlist_df

# %%
results = track_reccommender(df, track, include_pop=True)
results
# Out:
#        artist_name                track_id  popularity  acousticness  \
# 9295       Cardi B  4Oun2ylbjFKMPTiaSbbCih        0.97      0.019400
# 48       21 Savage  2fQrGHiQOvpL9UgPvtYy6G        0.84      0.015100
# 155         Future  0VgkVdmE4gld66l8iyGjgx        0.82      0.010200
# 1389  XXXTENTACION  5b6zjsBrZCqe6RFycLz2tc        0.67      0.076200
# 194          Drake  4Kz4RdRCceaA9VgTqBhBfa        0.75      0.000107
# 243      21 Savage  2wOXxtHZgRkkrkEbKLzzqs        0.77      0.000244
# 448         Future  4VMiNOpnjRwSCwmHaUfOMM        0.72      0.011700
# 166    ScHoolboy Q  4LmAnpjlhWTahvRkYR8xJa        0.77      0.020100
# 1553      Fat Nick  3Bo3lNVQTtZYMCoItX8dKW        0.68      0.000960
# 1310        Future  6DB2KOEwHnjkgEnBt5SdeJ        0.71      0.011100
# 57    Metro Boomin  2Grb4G6t9VIqo6moKUloom        0.81      0.006610
# 2844    KAYTRANADA  2b4SSorCTQ2VzmllaeWuuT        0.66      0.032300
# 564          Drake  3mvYQKm8h6M5K5h0nVPY9S        0.71      0.041400
# 210          Drake  2bjwRfXMk4uRgOD9IBYl9h        0.76      0.014300
# 1742     Young M.A  4JsKaTag0OHXibnqYcDfIA        0.65      0.077600
#
#       danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 9295         0.935   0.454          0.000000    0.0824    -7.509        0.375
# 48           0.884   0.346          0.000007    0.0871    -8.228        0.351
# 155          0.833   0.434          0.021900    0.1650    -8.795        0.431
# 1389         0.606   0.349          0.071100    0.1000   -10.032        0.198
# 194          0.766   0.442          0.000061    0.1110    -8.558        0.356
# 243          0.885   0.520          0.000001    0.4540    -8.353        0.359
# 448          0.730   0.465          0.000000    0.2800    -6.290        0.278
# 166          0.768   0.471          0.000000    0.2680    -8.406        0.259
# 1553         0.723   0.459          0.000000    0.1100   -10.259        0.239
# 1310         0.727   0.431          0.016600    0.5060   -12.007        0.395
# 57           0.870   0.350          0.000483    0.1080    -6.082        0.277
# 2844         0.824   0.396          0.002890    0.1080    -9.663        0.332
# 564          0.686   0.428          0.000000    0.1380   -13.072        0.192
# 210          0.924   0.444          0.000000    0.2600    -8.227        0.243
# 1742         0.617   0.420          0.000004    0.3960    -5.165        0.259
#
#         tempo  valence     score
# 9295  133.073    0.357  1.000000
# 48     75.016    0.376  0.997328
# 155   150.062    0.281  0.996250
# 1389  180.055    0.239  0.995345
# 194   201.800    0.390  0.994348
# 243    84.022    0.306  0.993051
# 448   148.028    0.367  0.992899
# 166   131.023    0.405  0.992471
# 1553  139.972    0.313  0.992404
# 1310  150.005    0.223  0.992364
# 57     74.963    0.175  0.992272
# 2844  118.053    0.252  0.992211
# 564   141.950    0.329  0.992062
# 210   136.088    0.314  0.991984
# 1742   87.150    0.213  0.991875

# %%
results.columns
# Out:
# Index(['artist_name', 'track_id', 'popularity', 'acousticness', 'danceability',
#        'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness',
#        'tempo', 'valence', 'score'],
#       dtype='object')

# %%
cols = ['artist_name','score', 'popularity', 'danceability',
       'energy', 'valence', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'loudness','tempo',
       'track_id']
results = results[cols]
results
# Out:
#        artist_name     score  popularity  danceability  energy  valence  \
# 9295       Cardi B  1.000000        0.97         0.935   0.454    0.357
# 48       21 Savage  0.997328        0.84         0.884   0.346    0.376
# 155         Future  0.996250        0.82         0.833   0.434    0.281
# 1389  XXXTENTACION  0.995345        0.67         0.606   0.349    0.239
# 194          Drake  0.994348        0.75         0.766   0.442    0.390
# 243      21 Savage  0.993051        0.77         0.885   0.520    0.306
# 448         Future  0.992899        0.72         0.730   0.465    0.367
# 166    ScHoolboy Q  0.992471        0.77         0.768   0.471    0.405
# 1553      Fat Nick  0.992404        0.68         0.723   0.459    0.313
# 1310        Future  0.992364        0.71         0.727   0.431    0.223
# 57    Metro Boomin  0.992272        0.81         0.870   0.350    0.175
# 2844    KAYTRANADA  0.992211        0.66         0.824   0.396    0.252
# 564          Drake  0.992062        0.71         0.686   0.428    0.329
# 210          Drake  0.991984        0.76         0.924   0.444    0.314
# 1742     Young M.A  0.991875        0.65         0.617   0.420    0.213
#
#       speechiness  acousticness  instrumentalness  liveness  loudness  \
# 9295        0.375      0.019400          0.000000    0.0824    -7.509
# 48          0.351      0.015100          0.000007    0.0871    -8.228
# 155         0.431      0.010200          0.021900    0.1650    -8.795
# 1389        0.198      0.076200          0.071100    0.1000   -10.032
# 194         0.356      0.000107          0.000061    0.1110    -8.558
# 243         0.359      0.000244          0.000001    0.4540    -8.353
# 448         0.278      0.011700          0.000000    0.2800    -6.290
# 166         0.259      0.020100          0.000000    0.2680    -8.406
# 1553        0.239      0.000960          0.000000    0.1100   -10.259
# 1310        0.395      0.011100          0.016600    0.5060   -12.007
# 57          0.277      0.006610          0.000483    0.1080    -6.082
# 2844        0.332      0.032300          0.002890    0.1080    -9.663
# 564         0.192      0.041400          0.000000    0.1380   -13.072
# 210         0.243      0.014300          0.000000    0.2600    -8.227
# 1742        0.259      0.077600          0.000004    0.3960    -5.165
#
#         tempo                track_id
# 9295  133.073  4Oun2ylbjFKMPTiaSbbCih
# 48     75.016  2fQrGHiQOvpL9UgPvtYy6G
# 155   150.062  0VgkVdmE4gld66l8iyGjgx
# 1389  180.055  5b6zjsBrZCqe6RFycLz2tc
# 194   201.800  4Kz4RdRCceaA9VgTqBhBfa
# 243    84.022  2wOXxtHZgRkkrkEbKLzzqs
# 448   148.028  4VMiNOpnjRwSCwmHaUfOMM
# 166   131.023  4LmAnpjlhWTahvRkYR8xJa
# 1553  139.972  3Bo3lNVQTtZYMCoItX8dKW
# 1310  150.005  6DB2KOEwHnjkgEnBt5SdeJ
# 57     74.963  2Grb4G6t9VIqo6moKUloom
# 2844  118.053  2b4SSorCTQ2VzmllaeWuuT
# 564   141.950  3mvYQKm8h6M5K5h0nVPY9S
# 210   136.088  2bjwRfXMk4uRgOD9IBYl9h
# 1742   87.150  4JsKaTag0OHXibnqYcDfIA

# %%
make_track_URIs(results['track_id'])
# Out:
# ['spotify:track:4Oun2ylbjFKMPTiaSbbCih',
#  'spotify:track:2fQrGHiQOvpL9UgPvtYy6G',
#  'spotify:track:0VgkVdmE4gld66l8iyGjgx',
#  'spotify:track:5b6zjsBrZCqe6RFycLz2tc',
#  'spotify:track:4Kz4RdRCceaA9VgTqBhBfa',
#  'spotify:track:2wOXxtHZgRkkrkEbKLzzqs',
#  'spotify:track:4VMiNOpnjRwSCwmHaUfOMM',
#  'spotify:track:4LmAnpjlhWTahvRkYR8xJa',
#  'spotify:track:3Bo3lNVQTtZYMCoItX8dKW',
#  'spotify:track:6DB2KOEwHnjkgEnBt5SdeJ',
#  'spotify:track:2Grb4G6t9VIqo6moKUloom',
#  'spotify:track:2b4SSorCTQ2VzmllaeWuuT',
#  'spotify:track:3mvYQKm8h6M5K5h0nVPY9S',
#  'spotify:track:2bjwRfXMk4uRgOD9IBYl9h',
#  'spotify:track:4JsKaTag0OHXibnqYcDfIA']

# %%
create_playlist_file(results['track_id'], 'cosine-sim')

# %%
display_playlist(make_track_URIs(results['track_id']))
# Out:
#                                               Title        Artist  \
# 1                   WAP (feat. Megan Thee Stallion)       Cardi B
# 2                                      Bank Account     21 Savage
# 3                                          Mask Off        Future
# 4                                     schizophrenia  XXXTENTACION
# 5                                         The Motto         Drake
# 6                                               1.5     21 Savage
# 7                                   Realer N Realer        Future
# 8                         X (with 2 Chainz & Saudi)   ScHoolboy Q
# 9                P.S Fuck You Cunt (feat. Lil Peep)      Fat Nick
# 10          Mask Off (feat. Kendrick Lamar) - Remix        Future
# 11        Don't Come Out The House (with 21 Savage)  Metro Boomin
# 12                                   YOU'RE THE ONE    KAYTRANADA
# 13  After Dark (feat. Static Major & Ty Dolla $ign)         Drake
# 14                                         Portland         Drake
# 15                                     Stubborn Ass     Young M.A
#
#                                                 Album
# 1                     WAP (feat. Megan Thee Stallion)
# 2                                          Issa Album
# 3                                              FUTURE
# 4                                                   ?
# 5                                  Take Care (Deluxe)
# 6                                        i am > i was
# 7        Future & Juice WRLD Present... WRLD ON DRUGS
# 8   Black Panther The Album Music From And Inspire...
# 9                              When the Lean Runs Out
# 10            Mask Off (feat. Kendrick Lamar) [Remix]
# 11                 NOT ALL HEROES WEAR CAPES (Deluxe)
# 12                                              99.9%
# 13                                           Scorpion
# 14                                          More Life
# 15                                       Stubborn Ass

# %% [markdown]
# ## Try it without Popularity <a class="anchor" id="topic-2"></a>
# <hr/>

# %%
results_nopop = track_reccommender(df, track, include_pop=False)

# %%
results_nopop
# Out:
#              artist_name                track_id  popularity  acousticness  \
# 3113  The Sugarhill Gang  0FWhGmPVxLI6jOVF0wjALa        0.56      0.465000
# 3191            Ice Cube  4r13PlX7hKjNxdyq5ukR5A        0.63      0.000917
# 3627         $uicideBoy$  6OB7Xp69uSWA4vDwcKgEDA        0.60      0.119000
# 4543              Noname  1XiKRU9Dg7QPlGRSWbfXgo        0.57      0.091000
# 4749              G-Eazy  6uz0z5oMeC8QWfTHeR5qlF        0.56      0.241000
# 4854            Lil Pump  6ox6GMJt3WP2QghksDa6UO        0.60      0.026300
# 4922           Key Glock  3RHOFe6m1g0nCZ7CClVKn0        0.54      0.001340
# 5873         Young Dolph  0xSLJxGbnhA6FHtar3CEmc        0.51      0.106000
# 6969         2 LIVE CREW  0ioFIQXbTUaliQpsJyX4zN        0.49      0.001070
# 7329                EPMD  0f1yzIIGD8k32DNVeEn6jb        0.50      0.089000
# 7743           MadeinTYO  3fCRwVGeNXfW2snoDxhwsM        0.49      0.235000
# 8273         ScHoolboy Q  7fQzRNL3k0YUkhTTSuZgcg        0.49      0.072400
# 8516               Valee  5ialuE8pZWhdGgVbT8VDui        0.47      0.037400
# 9113            Ice Cube  6g1PQiyoaop6ktk2TLchtR        0.52      0.000924
# 9210              Twista  5y8WWi1BaKHXfuln0XoIZs        0.58      0.261000
#
#       danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 3113         0.900   0.845          0.000000    0.0724    -7.306        0.257
# 3191         0.946   0.857          0.000000    0.0525    -4.498        0.159
# 3627         0.905   0.817          0.000000    0.1500    -4.260        0.397
# 4543         0.891   0.827          0.000002    0.2210    -6.139        0.351
# 4749         0.838   0.781          0.000000    0.1050    -8.249        0.450
# 4854         0.917   0.760          0.000000    0.0976    -3.290        0.380
# 4922         0.935   0.772          0.000028    0.1100    -8.773        0.354
# 5873         0.866   0.947          0.000000    0.6310    -5.365        0.272
# 6969         0.895   0.900          0.000661    0.2390    -8.905        0.195
# 7329         0.882   0.814          0.000000    0.1600    -5.214        0.424
# 7743         0.911   0.690          0.000000    0.0681    -3.901        0.414
# 8273         0.944   0.949          0.000000    0.3480    -5.606        0.190
# 8516         0.904   0.691          0.000000    0.1190    -6.835        0.526
# 9113         0.948   0.863          0.000000    0.0565    -4.361        0.170
# 9210         0.926   0.888          0.000000    0.3480    -5.337        0.294
#
#         tempo  valence
# 3113  111.187    0.914
# 3191   99.880    0.882
# 3627  140.083    0.800
# 4543  100.987    0.861
# 4749  135.941    0.913
# 4854  136.014    0.813
# 4922  139.999    0.875
# 5873  132.013    0.813
# 6969  131.671    0.896
# 7329   99.689    0.854
# 7743   87.999    0.933
# 8273  116.012    0.763
# 8516  140.161    0.918
# 9113   99.902    0.872
# 9210   98.523    0.819

# %%
display_playlist(make_track_URIs(results_nopop['track_id']))
# Out:
#                                        Title              Artist  \
# 1                           Rapper's Delight  The Sugarhill Gang
# 2   You Can Do It - Feat. Mack 10 And Ms Toi            Ice Cube
# 3                     HUNG UP ON THE COME UP         $uicideBoy$
# 4                             Blaxploitation              Noname
# 5    Loaded (Bonus Track) [feat. DJ Carnage]              G-Eazy
# 6           Smoke My Dope (feat. Smokepurpp)            Lil Pump
# 7                                       Dope           Key Glock
# 8                            What's the Deal         Young Dolph
# 9                               Hoochie Mama         2 LIVE CREW
# 10                         You Gots To Chill                EPMD
# 11                               Moshi Moshi           MadeinTYO
# 12                                  Big Body         ScHoolboy Q
# 13                                    Skinny               Valee
# 14                             You Can Do It            Ice Cube
# 15         Sunshine (feat. Anthony Hamilton)              Twista
#
#                                   Album
# 1     Rhino Hi-Five: The Sugarhill Gang
# 2   War & Peace Vol. 2 (The Peace Disc)
# 3                HUNG UP ON THE COME UP
# 4                               Room 25
# 5                          Must Be Nice
# 6                              Lil Pump
# 7                              Glockoma
# 8                     Thinking Out Loud
# 9    Goes To the Movies: Decade of Hits
# 10                    Strictly Business
# 11                     Sincerely, Tokyo
# 12                        Blank Face LP
# 13               GOOD Job, You Found Me
# 14                        Greatest Hits
# 15                             Kamikaze

# %%
Y = np.array([
    [1,2,3],
    [6,4,5],
    [9,7,8]
]
)

s = cosine_similarity(Y, Y)
s
# Out:
# array([[1.        , 0.88326011, 0.90184723],
#        [0.88326011, 1.        , 0.99819089],
#        [0.90184723, 0.99819089, 1.        ]])

# %%
s[1]
# Out:
# array([0.88326011, 1.        , 0.99819089])
